# %%
import seaborn as sns
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
# tips_df#load 'tips' DataFrame from Github seaborn repositry
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Plot Histogram of Size
sns.distplot(tips_df['size'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\4132993181.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['size'])
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.displot(tips_df['sex'])

# %%
sns.distplot(tips_df['total_bill'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\3759225478.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df['smoker'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\94991592.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['smoker'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.distplot(tips_df['smoker'])
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
#    2459 if a.ndim > 1:
#    2460     a = a.squeeze()
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
#     891           dtype='datetime64[ns]')
#     892     """
# --> 893     return np.asarray(self._values, dtype)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\_mixins.py:85, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      82 @wraps(meth)
#      83 def method(self, *args, **kwargs):
#      84     if self.ndim == 1:
# ---> 85         return meth(self, *args, **kwargs)
#      87     flags = self._ndarray.flags
#      88     flat = self.ravel("K")
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py:1609, in Categorical.__array__(self, dtype)
#    1607 ret = take_nd(self.categories._values, self._codes)
#    1608 if dtype and not is_dtype_equal(dtype, self.categories.dtype):
# -> 1609     return np.asarray(ret, dtype)
#    1610 # When we're a Categorical[ExtensionArray], like Interval,
#    1611 # we need to ensure __array__ gets all the way to an
#    1612 # ndarray.
#    1613 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'No'

# %%
sns.distplot(tips_df['day'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\75296702.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['day'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.distplot(tips_df['day'])
#
# File ~\anaconda3\lib\site-packages\seaborn\distributions.py:2458, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2455     a = x
#    2457 # Make a a 1-d float array
# -> 2458 a = np.asarray(a, float)
#    2459 if a.ndim > 1:
#    2460     a = a.squeeze()
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:893, in Series.__array__(self, dtype)
#     846 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     847     """
#     848     Return the values as a NumPy array.
#     849
#    (...)
#     891           dtype='datetime64[ns]')
#     892     """
# --> 893     return np.asarray(self._values, dtype)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\_mixins.py:85, in ravel_compat.<locals>.method(self, *args, **kwargs)
#      82 @wraps(meth)
#      83 def method(self, *args, **kwargs):
#      84     if self.ndim == 1:
# ---> 85         return meth(self, *args, **kwargs)
#      87     flags = self._ndarray.flags
#      88     flat = self.ravel("K")
#
# File ~\anaconda3\lib\site-packages\pandas\core\arrays\categorical.py:1609, in Categorical.__array__(self, dtype)
#    1607 ret = take_nd(self.categories._values, self._codes)
#    1608 if dtype and not is_dtype_equal(dtype, self.categories.dtype):
# -> 1609     return np.asarray(ret, dtype)
#    1610 # When we're a Categorical[ExtensionArray], like Interval,
#    1611 # we need to ensure __array__ gets all the way to an
#    1612 # ndarray.
#    1613 return np.asarray(ret)
#
# ValueError: could not convert string to float: 'Sun'

# %%
sns.distplot(tips_df['total_bill'],bins=55)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\1940629543.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'],bins=55)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips_df['total_bill'],bins=55)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\1940629543.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['total_bill'],bins=55)
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#Plot Histogram of "total_bill" with kde (kernal density estimator) parameters
sns.distplot(tips_df["total_bill"], kde=False,)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\351250271.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], kde=False,)
# <Axes: xlabel='total_bill'>

# %%
 sns.distplot(tips_df["total_bill"],hist = False )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\3056310212.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],hist = False )
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#Plot Histogram of "total_bill" with fit and kde parameters
sns.distplot(tips_df["total_bill"],fit=norm, kde = False)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\240229277.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],fit=norm, kde = False)
# <Axes: xlabel='total_bill'>

# %%
#Plot Histogram of "total_bill" with color parameters
sns.distplot(tips_df["total_bill"],color="r",) # pass red color
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12488\57877900.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"],color="r",) # pass red color
# <Axes: xlabel='total_bill', ylabel='Density'>
