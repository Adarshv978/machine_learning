# %%
import pandas as pd

# %%
# df =pd.read_csv('C:\\Users\\HP\\Downloads\\aadi.csv');
df = pd.read_csv('C:\\Users\\HP\\Downloads\\business-financial-data-september-2022-quarter-csv\\aadi.csv')
df
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars
# ...               ...      ...         ...        ...    ...      ...
# 6190     BDCQ.SF8RSCA  2021.09     382.195        NaN      F  Dollars
# 6191     BDCQ.SF8RSCA  2021.12     397.184        NaN      F  Dollars
# 6192     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0    BDCQ.SF1AA2CA  2016.06    1116.386        NaN      F  Dollars          6
# 1    BDCQ.SF1AA2CA  2016.09    1070.874        NaN      F  Dollars          6
# 2    BDCQ.SF1AA2CA  2016.12    1054.408        NaN      F  Dollars          6
# 3    BDCQ.SF1AA2CA  2017.03    1010.665        NaN      F  Dollars          6
# 4    BDCQ.SF1AA2CA  2017.06    1233.700        NaN      F  Dollars          6
#
#                           Subject  \
# 0  Business Data Collection - BDC
# 1  Business Data Collection - BDC
# 2  Business Data Collection - BDC
# 3  Business Data Collection - BDC
# 4  Business Data Collection - BDC
#
#                                              Group            Series_title_1  \
# 0  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# 1  Industry by financial variable (NZSIOC Level 2)  Sales (operating income)
# ...

# %%
df.tail()
# Out:
#      Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 6190     BDCQ.SF8RSCA  2021.09     382.195        NaN      F  Dollars
# 6191     BDCQ.SF8RSCA  2021.12     397.184        NaN      F  Dollars
# 6192     BDCQ.SF8RSCA  2022.03     493.945        NaN      F  Dollars
# 6193     BDCQ.SF8RSCA  2022.06     579.955        NaN      R  Dollars
# 6194     BDCQ.SF8RSCA  2022.09     609.161        NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 6190          6  Business Data Collection - BDC
# 6191          6  Business Data Collection - BDC
# 6192          6  Business Data Collection - BDC
# 6193          6  Business Data Collection - BDC
# 6194          6  Business Data Collection - BDC
#
#                                                 Group    Series_title_1  \
# 6190  Industry by financial variable (NZSIOC Level 1)  Operating profit
# 6191  Industry by financial variable (NZSIOC Level 1)  Operating profit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6195 entries, 0 to 6194
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  6195 non-null   object
#  1   Period            6195 non-null   float64
#  2   Data_value        5720 non-null   float64
#  3   Suppressed        15 non-null     object
#  4   STATUS            6195 non-null   object
#  5   UNITS             6195 non-null   object
#  6   Magnitude         6195 non-null   int64
#  7   Subject           6195 non-null   object
#  8   Group             6195 non-null   object
#  9   Series_title_1    6195 non-null   object
#  10  Series_title_2    6195 non-null   object
#  11  Series_title_3    6195 non-null   object
#  12  Series_title_4    6195 non-null   object
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 677.7+ KB

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.7.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x= np.array([1,20])
y = np.array([29,1002])
abc = plt.plot(x,y)
# abc.show()

# %%
plt.plot(x,y,'o')

# %%
x=np.array([10,20,30,40,50])
y= np.array([45,35,25,15,52])
plt.plot(x,y)

# %%
x= np.array([12,2,20,2])
plt.plot(x,marker='o')

# %%
x= np.array([12,2,20,2])
plt.plot(x,marker='*')

# %%
x= np.array([12,2,20,2])
plt.plot(x,marker='o',linestyle='dotted')

# %%
x= np.array([12,2,20,2])
plt.plot(x,marker='o',linestyle = 'dashed')

# %%
x= np.array([12,2,20,2])
plt.plot(x,marker='o',linestyle = 'dashed',color='r')

# %%
x= np.array([12,2,20,2])
plt.plot(x,marker='o',linestyle = 'dashed',linewidth='2.5')

# %%
x1 = np.array([1,4,3,4])
x2 = np.array([2,3,4,5])
y1 = np.array([3,4,5,6])
y2 = np.array([5,6,7,8])

plt.plot(x1,y1,x2,y2)

# %%
x1 = np.array([1,4,3,4])
x2 = np.array([2,3,4,5])
y1 = np.array([3,4,5,6])
y2 = np.array([5,6,7,8])
font1 = {'family':'serif','color':'r','size':10}
font2 = {'family':'serif','color':'b','size':20}
plt.title('Plot chart of the trip to temples',loc='right')
plt.xlabel("x axis",fontdict=font1)
plt.ylabel("y axis",fontdict = font2)

plt.plot(x1,y1,x2,y2)

# %%
x1 = np.array([1,4,3,4])
x2 = np.array([2,3,4,5])
y1 = np.array([3,4,5,6])
y2 = np.array([5,6,7,8])
font1 = {'family':'serif','color':'r','size':10}
font2 = {'family':'serif','color':'b','size':20}
plt.title('Plot chart of the trip to temples',loc='right')
plt.xlabel("x axis",fontdict=font1)
plt.ylabel("y axis",fontdict = font2)
plt.grid()


plt.plot(x1,y1,x2,y2)

# %%
x1 = np.array([1,4,3,4])
x2 = np.array([2,3,4,5])
y1 = np.array([3,4,5,6])
y2 = np.array([5,6,7,8])
font1 = {'family':'serif','color':'r','size':10}
font2 = {'family':'serif','color':'b','size':20}
plt.title('Plot chart of the trip to temples',loc='right')
plt.xlabel("x axis",fontdict=font1)
plt.ylabel("y axis",fontdict = font2)
plt.grid(axis = 'x')


plt.plot(x1,y1,x2,y2)

# %%
x1 = np.array([1,4,3,4])
x2 = np.array([2,3,4,5])
y1 = np.array([3,4,5,6])
y2 = np.array([5,6,7,8])
font1 = {'family':'serif','color':'r','size':10}
font2 = {'family':'serif','color':'b','size':20}
plt.title('Plot chart of the trip to temples',loc='right')
plt.xlabel("x axis",fontdict=font1)
plt.ylabel("y axis",fontdict = font2)
plt.grid(axis ='y')


plt.plot(x1,y1,x2,y2)

# %%
x1 = np.array([1,4,3,4])
x2 = np.array([2,3,4,5])
y1 = np.array([3,4,5,6])
y2 = np.array([5,6,7,8])
font1 = {'family':'serif','color':'r','size':10}
font2 = {'family':'serif','color':'b','size':20}
plt.title('Plot chart of the trip to temples',loc='right')
plt.xlabel("x axis",fontdict=font1)
plt.ylabel("y axis",fontdict = font2)
plt.grid(color='gray' ,linestyle ='--' ,linewidth='1.0')


plt.plot(x1,y1,x2,y2)

# %%
# # Plot 1
# x= np.array([27,2,19,10])
# y= np.array([3,8,1,10,10])
# plt.subplot(1, 2, 1)
# plt.plot(x,y)
# plt.show()
# # Plot 2
# x2 = np.array([1,23,11,12])
# y2 = np.array([10,13,111,62])
# plt.plot(2,1,1)
# plt.plot(x2,y2)



#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
# the sub plot parameter 1 row ,2 is column and third parameter  is reprasent that  no of plot 1,2nd or third 
plt.plot(x,y)

plt.show()

# %%
# Plot 1
x1=np.array([100,14,26,19])
y1 = np.array([91,36,25,37])
plt.subplot(2,1,1)
plt.plot(x1,y1)

# plot 2
x2 = np.array([12,18,20,30,17])
y2 = np.array([18,20,30,17,12])
plt.subplot(2,1,2)
plt.plot(x2,y2)

# %%
# plot 1
x= np.array([10,2,20,38])
y = np.array([83,28,19,29])
plt.subplot(1,2,1)
plt.plot(x,y)

# plot 2
x= np.array([10,2,20,38])
y = np.array([83,28,19,29])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
# plot 1
x= np.array([10,2,20,38])
y = np.array([83,28,19,29])
plt.subplot(1,2,1)
plt.plot(x,y)

# plot 2
x= np.array([10,2,20,38])
y = np.array([83,28,19,29])
plt.subplot(1,2,2)
plt.plot(x,y)


# plot 3
x= np.array([10,2,20,38])
y = np.array([83,28,19,29])
plt.subplot(1,3,3)
plt.plot(x,y)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9360\3177234387.py:17: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,3)

# %%
# plot 1
x= np.array([10,29,8,20])
y= np.array([28,29,19,19])
plt.subplot(2,1,1)
plt.plot(x,y)
plt.title('Online Path puja || Trip to temple || Plane my Package')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# plot 2
x= np.array([10,29,8,20])
y= np.array([28,29,19,19])
plt.subplot(2,1,2)
plt.plot(x,y)
font1 = {'family':'serif','color':'r','size':10}
font2 = {'family':'serif','color':'b','size':20}
plt.title('Online Path puja || Trip to temple || Plane my Package')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
# np.randint(10,20)

abc = np.random.randint(1,100,20)
xyz = np.random.randint(200,250,20)


print(abc)
print(xyz)
x = np.array(abc)
y = np.array(xyz)

plt.scatter(x,y)
plt.show()
# Out:
# [87 51  9 48 35 26 16 77 23 11 20 76 94 12 16 71 86 10 23 40]
# [218 219 200 229 221 213 224 221 246 216 208 248 244 202 204 230 203 231
#  214 245]

# %%
# import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
# import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y,color = '#FFA500')

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y ,color = 'pink')

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y,color = colors , cmap='viridis')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9360\216480958.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,color = colors , cmap='viridis')

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
a = np.array(np.random.randint(1,100,20))
b = np.array(np.random.randint(200,300,30))
plt.bar(x,y)
plt.show()

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
# Out:
# (array([ 3.,  3.,  9., 23., 41., 73., 53., 34.,  7.,  4.]),
#  array([134.5948435 , 140.72374094, 146.85263839, 152.98153583,
#         159.11043327, 165.23933071, 171.36822815, 177.49712559,
#         183.62602303, 189.75492047, 195.88381791]),
#  <BarContainer object of 10 artists>)

# %%
y = np.array([35, 25, 25, 15])
mylabels = ['Apple','Banana','Orange','Payaya']

plt.pie(y,labels = mylabels)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ['Apple','Banana','Orange','Payaya']

plt.pie(y,labels = mylabels ,startangle = 90)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ['Apple','Banana','Orange','Payaya']

myexplode = [0.02,0,0,0]

plt.pie(y,labels = mylabels , explode =myexplode)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ['Apple','Banana','Orange','Payaya']

myexplode = [0.2,0,0,0]


plt.pie(y, labels = mylabels , explode = myexplode ,shadow = True)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ['Apple','Banana','Orange','Payaya']

myexplode = [0.2,0,0,0]

mycolors = ['pink','yellow','red','orange']
plt.pie(y, labels = mylabels , explode = myexplode ,shadow = True, colors = mycolors)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ['Apple','Banana','Orange','Payaya']

myexplode = [0.2,0,0,0]

mycolors = ['pink','yellow','red','orange']
plt.pie(y, labels = mylabels , explode = myexplode ,shadow = True, colors = mycolors)
plt.legend(title= "Four fruts")
plt.show()
