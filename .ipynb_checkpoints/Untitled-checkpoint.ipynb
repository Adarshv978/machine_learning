# %%
import seaborn as sns
from scipy.stats import norm
import matplotlib.pyplot as plt

# %%
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips_df['size'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6172\3999728182.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df['size'])
# <Axes: xlabel='size', ylabel='Density'>

# %%
plt.figure(figsize=(16,9))
sns.distplot(tips_df["total_bill"], bins=9, label="total_bil")
sns.distplot(tips_df["tip"], bins=9, label="tip")
sns.distplot(tips_df["size"], bins=9, label = "size")
 
plt.legend()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6172\3237677672.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips_df["total_bill"], bins=9, label="total_bil")
# C:\Users\HP\AppData\Local\Temp\ipykernel_6172\3237677672.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
tips_df = sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
 sns.barplot( x=None,
                                     y=None,
                                     hue=None,
                                     data=None,
                                     order=None,
                                     hue_order=None,
                                     estimator=<function mean at 0x0000026F155D02F0>,
                                     ci=95,
                                     n_boot=1000,
                                     units=None,
                                     orient=None,
                                     color=None,
                                     palette=None,
                                     saturation=0.75,
                                     errcolor=’.26′,
                                     errwidth=None,
                                     capsize=None,
                                     dodge=True,
                                     ax=None,
                                     **kwargs,
                                    )
# Out:
#   Cell In[9], line 1
#     sns.barplot(
#                ^
# SyntaxError: '(' was never closed

# %%
sns.barplot(tips_df)
# Out:
# <Axes: >

# %%
sns.barplot(x=tips_df.day,y=tips_df.total_bill)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x=tips_df.day,y=tips_df.total_bill,hue=tips_df.sex)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day', y = 'total_bill', hue = 'sex',
           data = tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex', data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.max)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.median)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,n_boot=2
           )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(y='day',x='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,n_boot=2
           )
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,n_boot=2
,ci=10           )
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6172\1078944431.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 10)` for the same effect.
#
#   sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,n_boot=2
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,n_boot=2
,errorbar=('ci', 10)         )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink'      )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="magma"   )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted"   )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,saturation=0.3)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,errcolor='0.2')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,errcolor='0.2',errwidth=5)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,errcolor='0.2',errwidth=5,capsize=1)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,errcolor='0.2',errwidth=1.9,capsize=0.1,dodge=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
kwargs = {'alpha':1, 'linestyle':':', 'linewidth':2, 'edgecolor':'k'}
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,errcolor='0.2',errwidth=1.9,capsize=0.1,**kwargs)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
kwargs = {'alpha':1, 'linestyle':'-.', 'linewidth':2, 'edgecolor':'k'}
sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,errcolor='0.2',errwidth=1.9,capsize=0.1,**kwargs)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
orders=['Sat','Sun','Fri','Thur']
kwargs = {'alpha':1, 'linestyle':'-.', 'linewidth':2, 'edgecolor':'b'}
ax=sns.barplot(x='day',y='total_bill',data=tips_df,hue='sex',order=orders ,hue_order = ['Female','Male'],estimator=np.min,
 color='pink' ,  palette="twilight_shifted" ,errcolor='0.2',errwidth=1.9,capsize=0.1,**kwargs)
ax.set(title = "Barplot of Tips DataFrame",
      xlabel = "Days",
      ylabel = "Total Bill")
# Out:
# [Text(0.5, 1.0, 'Barplot of Tips DataFrame'),
#  Text(0.5, 0, 'Days'),
#  Text(0, 0.5, 'Total Bill')]

# %%
sns.set()
plt.figure(figsize = (16,9))
plt.title("Barplot of Days and Total Bill", fontsize = 20)
plt.xlabel("Days", fontsize = 15)
plt.ylabel("Total Bill", fontsize = 15)
 
plt.savefig("Barplot of Days and Total Bill")
plt.show()
